# %% [markdown]
# # Simple Moving Averages for Stocks

# %% [markdown]
# ## Import libraries

# %%
pip install yfinance

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
plt.style.use("seaborn-whitegrid")

# %% [markdown]
# ## Load stock data

# %%
ticker = "AAPL"
aapl_df = yf.download(tickers=ticker, period="max", interval="1d", group_by="ticker", auto_adjust=True)
aapl_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close     Volume
# Date
# 1980-12-12    0.100600    0.101037    0.100600    0.100600  469033600
# 1980-12-15    0.095789    0.095789    0.095352    0.095352  175884800
# 1980-12-16    0.088790    0.088790    0.088353    0.088353  105728000
# 1980-12-17    0.090540    0.090977    0.090540    0.090540   86441600
# 1980-12-18    0.093165    0.093602    0.093165    0.093165   73449600
# ...                ...         ...         ...         ...        ...
# 2021-08-03  145.591857  147.818517  144.962795  147.139542   64786600
# 2021-08-04  147.049692  147.568903  146.061168  146.730164   56368300
# 2021-08-05  146.760114  147.618828  145.951328  146.839996   46397700
# 2021-08-06  146.350006  147.110001  145.630005  146.139999   54067400
# 2021-08-09  146.199997  146.699997  145.520004  146.089996   48853100
#
# [10251 rows x 5 columns]

# %%
aapl_df = aapl_df.loc["2019-01-01":]
aapl_df
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2019-01-02   37.645792   38.608266   37.485379   38.382229  148158800
# 2019-01-03   34.994134   35.417039   34.512898   34.559078  365248800
# 2019-01-04   35.127801   36.104857   34.950376   36.034370  234428400
# 2019-01-07   36.141319   36.172916   35.460782   35.954170  219111200
# 2019-01-08   36.350336   36.899628   36.097567   36.639565  164101200
# ...                ...         ...         ...         ...        ...
# 2021-08-03  145.591857  147.818517  144.962795  147.139542   64786600
# 2021-08-04  147.049692  147.568903  146.061168  146.730164   56368300
# 2021-08-05  146.760114  147.618828  145.951328  146.839996   46397700
# 2021-08-06  146.350006  147.110001  145.630005  146.139999   54067400
# 2021-08-09  146.199997  146.699997  145.520004  146.089996   48853100
#
# [656 rows x 5 columns]

# %% [markdown]
# ## Visualise Adjusted Close Prices

# %%
plt.figure(figsize=(16,8))
plt.title("Adj Close Price History since 2017", fontsize=18)
plt.plot(aapl_df["Close"])
plt.xlabel("Date", fontsize=18)
plt.ylabel("Adj Close", fontsize=18)
plt.show()

# %% [markdown]
# ## Simple Moving Average (SMA)

# %%
def SMA(data, period, column="Close"):
  return data[column].rolling(window=period).mean()

# %%
aapl_df.loc[:,"SMA20"] = SMA(aapl_df, 20)
aapl_df.loc[:,"SMA50"] = SMA(aapl_df, 50)

# %%
aapl_df.head(50)
# Out:
#                  Open       High        Low  ...     Volume      SMA20      SMA50
# Date                                         ...
# 2019-01-02  37.645792  38.608266  37.485379  ...  148158800        NaN        NaN
# 2019-01-03  34.994134  35.417039  34.512898  ...  365248800        NaN        NaN
# 2019-01-04  35.127801  36.104857  34.950376  ...  234428400        NaN        NaN
# 2019-01-07  36.141319  36.172916  35.460782  ...  219111200        NaN        NaN
# 2019-01-08  36.350336  36.899628  36.097567  ...  164101200        NaN        NaN
# 2019-01-09  36.770813  37.558292  36.367355  ...  180396400        NaN        NaN
# 2019-01-10  37.064903  37.422185  36.666304  ...  143122800        NaN        NaN
# 2019-01-11  37.157264  37.356562  36.824285  ...  108092800        NaN        NaN
# 2019-01-14  36.663880  36.765960  36.267709  ...  129756800        NaN        NaN
# 2019-01-15  36.522905  37.281215  36.469434  ...  114843600        NaN        NaN
# 2019-01-16  37.205869  37.886406  37.186425  ...  122278800        NaN        NaN
# 2019-01-17  37.478081  38.319030  37.249615  ...  119284800        NaN        NaN
# 2019-01-18  38.280143  38.372503  37.910708  ...  135004000        NaN        NaN
# 2019-01-22  38.015227  38.093001  37.094071  ...  121576000        NaN        NaN
# 2019-01-23  37.465930  37.706550  36.870462  ...   92522400        NaN        NaN
# 2019-01-24  37.456217  37.546144  36.880193  ...  101766000        NaN        NaN
# 2019-01-25  37.789180  38.433261  37.507247  ...  134142000        NaN        NaN
# 2019-01-28  37.864534  37.995782  37.346843  ...  104768400        NaN        NaN
# 2019-01-29  37.976341  38.433274  37.456218  ...  166348800        NaN        NaN
# 2019-01-30  39.677672  40.382511  38.943664  ...  244439200  37.320712        NaN
# 2019-01-31  40.372800  41.075211  39.996074  ...  162958400  37.424251        NaN
# 2019-02-01  40.579392  41.070348  40.329049  ...  130672400  37.719919        NaN
# 2019-02-04  40.688753  41.721710  40.657156  ...  125982000  37.999304        NaN
# 2019-02-05  42.013376  42.552944  41.889422  ...  144406400  38.318305        NaN
# 2019-02-06  42.448425  42.672033  42.010940  ...  112958400  38.603766        NaN
# 2019-02-07  41.901567  42.275864  41.400888  ...  126966800  38.818013        NaN
# 2019-02-08  41.248927  41.656558  41.109793  ...   95280000  39.028746        NaN
# 2019-02-11  41.751757  41.790812  41.312392  ...   83973600  39.245870        NaN
# 2019-02-12  41.519877  41.739558  41.422239  ...   89134000  39.508641        NaN
# 2019-02-13  41.834746  42.100804  41.475932  ...   89960800  39.725438        NaN
# 2019-02-14  41.424680  41.803018  41.344130  ...   87342800  39.927078        NaN
# 2019-02-15  41.800569  41.910409  41.434432  ...   98507200  40.112900        NaN
# 2019-02-19  41.424678  41.846954  41.370978  ...   75891200  40.293279        NaN
# 2019-02-20  41.785931  42.305846  41.737114  ...  104457600  40.529860        NaN
# 2019-02-21  41.934825  42.073955  41.568688  ...   68998800  40.747069        NaN
# 2019-02-22  41.881131  42.227739  41.832313  ...   75652800  41.002414        NaN
# 2019-02-25  42.510881  42.928275  42.459620  ...   87493600  41.211646        NaN
# 2019-02-26  42.401041  42.789144  42.269229  ...   68280800  41.439840        NaN
# 2019-02-27  42.278997  42.715918  42.161831  ...  111341600  41.694311        NaN
# 2019-02-28  42.549941  42.693953  42.208211  ...  112861600  41.799340        NaN
# 2019-03-01  42.540176  42.752534  42.200889  ...  103544800  41.912120        NaN
# 2019-03-04  42.884334  43.387161  42.464497  ...  109744800  42.034667        NaN
# 2019-03-05  42.945354  42.959999  42.603625  ...   78949600  42.095828        NaN
# 2019-03-06  42.635367  42.835523  42.457182  ...   83241600  42.109056        NaN
# 2019-03-07  42.440093  42.579227  41.988527  ...   99185600  42.096901        NaN
# 2019-03-08  41.573570  42.244820  41.373414  ...   95997600  42.129854        NaN
# 2019-03-11  42.835526  43.721574  42.801353  ...  128044000  42.233471        NaN
# 2019-03-12  43.936373  44.588096  43.782595  ...  129870400  42.373579        NaN
# 2019-03-13  44.485571  44.741867  44.160930  ...  124130000  42.505632        NaN
# 2019-03-14  44.888316  44.937137  44.561235  ...   94318000  42.671003  40.296309
#
# [50 rows x 7 columns]

# %% [markdown]
# ## Visualise SMA on top of Adj Close

# %%
aapl_df.loc[:,("Close", "SMA20", "SMA50")].plot(figsize=(16,8), legend=True, linewidth=2)
plt.legend(fontsize=18)
plt.title("Adj Close Price History since 2017", fontsize=18)
plt.xlabel("Date", fontsize=18)
plt.ylabel("Adj Close", fontsize=18)
plt.show()
