# %% [markdown]
# # Exponentially Weighted Moving Average (EWMA) for Stocks

# %% [markdown]
# ## Import libraries

# %%
pip install yfinance

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
plt.style.use("seaborn-whitegrid")

# %% [markdown]
# ## Load stock data

# %%
ticker = "AAPL"
aapl_df = yf.download(tickers=ticker, period="max", interval="1d", group_by="ticker", auto_adjust=True)
aapl_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close     Volume
# Date
# 1980-12-12    0.100600    0.101037    0.100600    0.100600  469033600
# 1980-12-15    0.095789    0.095789    0.095352    0.095352  175884800
# 1980-12-16    0.088790    0.088790    0.088353    0.088353  105728000
# 1980-12-17    0.090540    0.090977    0.090540    0.090540   86441600
# 1980-12-18    0.093165    0.093602    0.093165    0.093165   73449600
# ...                ...         ...         ...         ...        ...
# 2021-08-04  147.049692  147.568903  146.061168  146.730164   56368300
# 2021-08-05  146.760114  147.618828  145.951328  146.839996   46397700
# 2021-08-06  146.350006  147.110001  145.630005  146.139999   54067400
# 2021-08-09  146.199997  146.699997  145.520004  146.089996   48908700
# 2021-08-10  146.440002  147.710007  145.300003  145.600006   68922200
#
# [10252 rows x 5 columns]

# %%
aapl_df = aapl_df.loc["2019-01-01":]
aapl_df
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2019-01-02   37.645792   38.608266   37.485379   38.382229  148158800
# 2019-01-03   34.994134   35.417039   34.512898   34.559078  365248800
# 2019-01-04   35.127801   36.104857   34.950376   36.034370  234428400
# 2019-01-07   36.141319   36.172916   35.460782   35.954170  219111200
# 2019-01-08   36.350336   36.899628   36.097567   36.639565  164101200
# ...                ...         ...         ...         ...        ...
# 2021-08-04  147.049692  147.568903  146.061168  146.730164   56368300
# 2021-08-05  146.760114  147.618828  145.951328  146.839996   46397700
# 2021-08-06  146.350006  147.110001  145.630005  146.139999   54067400
# 2021-08-09  146.199997  146.699997  145.520004  146.089996   48908700
# 2021-08-10  146.440002  147.710007  145.300003  145.600006   68922200
#
# [657 rows x 5 columns]

# %% [markdown]
# ## Visualise adjusted close prices

# %%
plt.figure(figsize=(16,8))
plt.title("Adj Close Price History since 2017", fontsize=18)
plt.plot(aapl_df["Close"])
plt.xlabel("Date", fontsize=18)
plt.ylabel("Adj Close", fontsize=18)
plt.show()

# %% [markdown]
# ## Exponentially Weighted Moving Average (EWMA)

# %%
def EWMA(data, period, column="Close"):
  return data[column].ewm(span=period, adjust=False).mean()

# %%
aapl_df.loc[:,"EWMA21"] = EWMA(aapl_df, 21)

# %%
aapl_df.loc[:,"EWMA63"] = EWMA(aapl_df, 63)

# %%
aapl_df.head(10)
# Out:
#                  Open       High        Low  ...     Volume     EWMA21     EWMA63
# Date                                         ...
# 2019-01-02  37.645792  38.608266  37.485379  ...  148158800  38.382229  38.382229
# 2019-01-03  34.994134  35.417039  34.512898  ...  365248800  38.034670  38.262755
# 2019-01-04  35.127801  36.104857  34.950376  ...  234428400  37.852824  38.193118
# 2019-01-07  36.141319  36.172916  35.460782  ...  219111200  37.680219  38.123151
# 2019-01-08  36.350336  36.899628  36.097567  ...  164101200  37.585614  38.076789
# 2019-01-09  36.770813  37.558292  36.367355  ...  180396400  37.556174  38.051320
# 2019-01-10  37.064903  37.422185  36.666304  ...  143122800  37.540237  38.030368
# 2019-01-11  37.157264  37.356562  36.824285  ...  108092800  37.492385  37.998602
# 2019-01-14  36.663880  36.765960  36.267709  ...  129756800  37.398285  37.950436
# 2019-01-15  36.522905  37.281215  36.469434  ...  114843600  37.380572  37.927093
#
# [10 rows x 7 columns]

# %% [markdown]
# ## Visualise EMA on top of adjusted close prices

# %%
aapl_df.loc[:,("Close", "EWMA21", "EWMA63")].plot(figsize=(16,8), legend=True, linewidth=2)
plt.legend(fontsize=18)
plt.title("Adj Close Price History since 2017 w/ EWMAs", fontsize=18)
plt.xlabel("Date", fontsize=18)
plt.ylabel("Adj Close", fontsize=18)
plt.show()
